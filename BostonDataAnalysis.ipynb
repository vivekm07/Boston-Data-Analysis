# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Exploration and Visualization of Boston Data

# %%
data = pd.read_csv("MAJITHIA VIVEK VINODBHAI - bostondata.csv")

# %%
data
# Out:
#         CRIM  ZN  INDUS CHAS    NOX     RM        AGE     DIS RAD  TAX  \
# 0    0.00632  18   2.31    0  0.538  6.575  65.199997  4.0900   1  296
# 1    0.02731   0   7.07    0  0.469  6.421  78.900002  4.9671   2  242
# 2    0.02729   0   7.07    0  0.469  7.185  61.099998  4.9671   2  242
# 3    0.03237   0   2.18    0  0.458  6.998  45.799999  6.0622   3  222
# 4    0.06905   0   2.18    0  0.458  7.147  54.200001  6.0622   3  222
# ..       ...  ..    ...  ...    ...    ...        ...     ...  ..  ...
# 501  0.06263   0  11.93    0  0.573  6.593  69.099998  2.4786   1  273
# 502  0.04527   0  11.93    0  0.573  6.120  76.699997  2.2875   1  273
# 503  0.06076   0  11.93    0  0.573  6.976  91.000000  2.1675   1  273
# 504  0.10959   0  11.93    0  0.573  6.794  89.300003  2.3889   1  273
# 505  0.04741   0  11.93    0  0.573  6.030  80.800003  2.5050   1  273
#
#             PT           B  LSTAT         MV
# 0    15.300000  396.899994   4.98  24.000000
# ...

# %%
data.shape #number of rows and columns
# Out:
# (506, 14)

# %%
data.head(n=7) #first 7 lines
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM        AGE     DIS RAD  TAX  \
# 0  0.00632    18   2.31    0  0.538  6.575  65.199997  4.0900   1  296
# 1  0.02731     0   7.07    0  0.469  6.421  78.900002  4.9671   2  242
# 2  0.02729     0   7.07    0  0.469  7.185  61.099998  4.9671   2  242
# 3  0.03237     0   2.18    0  0.458  6.998  45.799999  6.0622   3  222
# 4  0.06905     0   2.18    0  0.458  7.147  54.200001  6.0622   3  222
# 5  0.02985     0   2.18    0  0.458  6.430  58.700001  6.0622   3  222
# 6  0.08829  12.5   7.87    0  0.524  6.012  66.599998  5.5605   5  311
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# 4  18.700001  396.899994   5.33  36.200001
# 5  18.700001  394.119995   5.21  28.700001
# 6  15.200000  395.600006  12.43  22.900000

# %%
data.dtypes
# Out:
# CRIM     float64
# ZN        object
# INDUS    float64
# CHAS      object
# NOX      float64
# RM       float64
# AGE      float64
# DIS      float64
# RAD       object
# TAX        int64
# PT       float64
# B        float64
# LSTAT    float64
# MV       float64
# dtype: object

# %%
data['ZN'] = data['ZN'].replace('#',None)
data.ZN.unique()
# Out:
# array(['18', '0', '12.5', '75', '21', '90', '85', '100', '25', '17.5',
#        '80', '28', '45', '60', '95', '82.5', '30', '22', '20', '40', '55',
#        '52.5', '70', '34', '33', '35'], dtype=object)

# %%
data['ZN'] = pd.to_numeric(data['ZN'],errors='coerce')
data['ZN'].unique()
# Out:
# array([ 18. ,   0. ,  12.5,  75. ,  21. ,  90. ,  85. , 100. ,  25. ,
#         17.5,  80. ,  28. ,  45. ,  60. ,  95. ,  82.5,  30. ,  22. ,
#         20. ,  40. ,  55. ,  52.5,  70. ,  34. ,  33. ,  35. ])

# %%
data['ZN'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # Removing unwanted characters

# %% [markdown]
# # CHAS:

# %%
data['CHAS'].unique()
# Out:
# array(['0', '?', '1'], dtype=object)

# %%
data['CHAS'] = data['CHAS'].replace('?',None)
data.CHAS.unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
data['CHAS'] = pd.to_numeric(data['CHAS'],errors='coerce')
data['CHAS'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# # RAD:

# %%
data['RAD'].unique()
# Out:
# array(['1', '2', '3', '5', '4', '#', '8', '6', '7', '24'], dtype=object)

# %%
data['RAD'] = data['RAD'].replace('#',None)
data['RAD'].unique()
# Out:
# array(['1', '2', '3', '5', '4', '8', '6', '7', '24'], dtype=object)

# %%
data['RAD'] = pd.to_numeric(data['RAD'],errors='coerce')
data['RAD'].dtypes
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# CRIM     float64
# ZN       float64
# INDUS    float64
# CHAS       int64
# NOX      float64
# RM       float64
# AGE      float64
# DIS      float64
# RAD        int64
# TAX        int64
# PT       float64
# B        float64
# LSTAT    float64
# MV       float64
# dtype: object

# %%
data.isnull().any()
# Out:
# CRIM     False
# ZN       False
# INDUS    False
# CHAS     False
# NOX      False
# RM       False
# AGE      False
# DIS      False
# RAD      False
# TAX      False
# PT       False
# B        False
# LSTAT    False
# MV       False
# dtype: bool

# %% [markdown]
# # Analysis and different properties of DataFrame:

# %%
data.head(8)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.700001  6.0622    3  222
# 6  0.08829  12.5   7.87     0  0.524  6.012  66.599998  5.5605    5  311
# 7  0.14455  12.5   7.87     0  0.524  6.172  96.099998  5.9505    5  311
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# 4  18.700001  396.899994   5.33  36.200001
# 5  18.700001  394.119995   5.21  28.700001
# ...

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976196  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX          PT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674030
# ...

# %%
data.iloc[3]
# Out:
# CRIM       0.032370
# ZN         0.000000
# INDUS      2.180000
# CHAS       0.000000
# NOX        0.458000
# RM         6.998000
# AGE       45.799999
# DIS        6.062200
# RAD        3.000000
# TAX      222.000000
# PT        18.700001
# B        394.630005
# LSTAT      2.940000
# MV        33.400002
# Name: 3, dtype: float64

# %% [markdown]
# # Slicing the data frame for some rows and some columns:

# %%
data.iloc[:8,:7]
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM        AGE
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.199997
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.900002
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.099998
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.799999
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.200001
# 5  0.02985   0.0   2.18     0  0.458  6.430  58.700001
# 6  0.08829  12.5   7.87     0  0.524  6.012  66.599998
# 7  0.14455  12.5   7.87     0  0.524  6.172  96.099998

# %% [markdown]
# # Selecting a few rows and columns based on conditions like in SQL for databases:

# %%
data[(data.ZN>15) & (data.RAD>6)]
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 58   0.15445  25.0   5.13     0  0.453  6.145  29.200001  7.8148    8  284
# 59   0.10328  25.0   5.13     0  0.453  5.927  47.200001  6.9320    8  284
# 60   0.14932  25.0   5.13     0  0.453  5.741  66.199997  7.2254    8  284
# 61   0.17171  25.0   5.13     0  0.453  5.966  93.400002  6.8185    8  284
# 62   0.11027  25.0   5.13     0  0.453  6.456  67.800003  7.2255    8  284
# 63   0.12650  25.0   5.13     0  0.453  6.762  43.400002  7.9809    8  284
# 244  0.20608  22.0   5.86     0  0.431  5.593  76.500000  7.9549    7  330
# 245  0.19133  22.0   5.86     0  0.431  5.605  70.199997  7.9549    7  330
# 246  0.33983  22.0   5.86     0  0.431  6.108  34.900002  8.0555    7  330
# 247  0.19657  22.0   5.86     0  0.431  6.226  79.199997  8.0555    7  330
# 248  0.16439  22.0   5.86     0  0.431  6.433  49.099998  7.8265    7  330
# ...

# %% [markdown]
# # Analysis of discrete variables including mode:

# %%
data.head(18)
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0   0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1   0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2   0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 3   0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 4   0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.900002  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.300003  6.3467    5  311
# ...

# %%
data['ZN CHAS INDUS NOX DIS RAD TAX PT B'.split(' ')].describe()
# Out:
#                ZN        CHAS       INDUS         NOX         DIS         RAD  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    11.363636    0.069170   11.136779    0.554695    3.795043    9.549407
# std     23.322453    0.253994    6.860353    0.115878    2.105710    8.707259
# min      0.000000    0.000000    0.460000    0.385000    1.129600    1.000000
# 25%      0.000000    0.000000    5.190000    0.449000    2.100175    4.000000
# 50%      0.000000    0.000000    9.690000    0.538000    3.207450    5.000000
# 75%     12.500000    0.000000   18.100000    0.624000    5.188425   24.000000
# max    100.000000    1.000000   27.740000    0.871000   12.126500   24.000000
#
#               TAX          PT           B
# count  506.000000  506.000000  506.000000
# mean   408.237154   18.455534  356.674030
# std    168.537116    2.164946   91.294863
# min    187.000000   12.600000    0.320000
# 25%    279.000000   17.400000  375.377487
# ...

# %%
data['ZN CHAS INDUS NOX DIS RAD TAX PT B'.split(' ')].mode()
# Out:
#     ZN  CHAS  INDUS    NOX     DIS  RAD  TAX         PT           B
# 0  0.0     0   18.1  0.538  3.4952   24  666  20.200001  396.899994

# %% [markdown]
# # Detailed descriptive analytics of continuous variables including max min variance mean median std and at least five percentiles:

# %%
data['CRIM RM AGE LSTAT MV'.split(' ')].describe()
# Out:
#              CRIM          RM         AGE       LSTAT          MV
# count  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524    6.284634   68.574901   12.653063   22.532806
# std      8.601545    0.702617   28.148862    7.141062    9.197104
# min      0.006320    3.561000    2.900000    1.730000    5.000000
# 25%      0.082045    5.885500   45.025000    6.950000   17.025000
# 50%      0.256510    6.208500   77.500000   11.360000   21.200001
# 75%      3.677083    6.623500   94.074999   16.954999   25.000000
# max     88.976196    8.780000  100.000000   37.970001   50.000000

# %%
data['CRIM RM AGE LSTAT MV'.split(' ')].mode()
# Out:
#        CRIM     RM    AGE      LSTAT    MV
# 0   0.01501  5.713  100.0   6.360000  50.0
# 1  14.33370  6.127    NaN   7.790000   NaN
# 2       NaN  6.167    NaN   8.050000   NaN
# 3       NaN  6.229    NaN  14.100000   NaN
# 4       NaN  6.405    NaN  18.129999   NaN
# 5       NaN  6.417    NaN        NaN   NaN

# %% [markdown]
# # Univariate plots for discrete columns and continuous columns:

# %% [markdown]
# # scatter plot for discrete:

# %%
plt.scatter(data.index,data.RM)

# %% [markdown]
# # scatter plot for continious column

# %%
plt.scatter(data.index,data.CRIM)

# %% [markdown]
# # Line plot for continious:

# %%
plt.plot(data.index,data.LSTAT,marker = 'd')

# %% [markdown]
# # Line plot for discrete:

# %%
plt.plot(data.index,data.INDUS,marker = 'd')

# %% [markdown]
# # strip plot for continious:

# %%
sns.stripplot(y = data.MV,marker = 'd')

# %% [markdown]
# # strip plot for discrete:

# %%
sns.stripplot(data.ZN,marker = 'd')

# %% [markdown]
# # Bivariate plot for two continuous columns:

# %% [markdown]
# # Line Plot:

# %%
data[['LSTAT','MV']].plot.line()

# %% [markdown]
# # Scatter plot:

# %%
plt.scatter(data['LSTAT'],data['MV'])

# %% [markdown]
# # Finding if the continuous columns have outliers using boxplot:

# %%
plt.boxplot(data['RM'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247def89b80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247def99280>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x247def89820>],
#  'medians': [<matplotlib.lines.Line2D at 0x247def99940>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247def99c40>],
#  'means': []}

# %%
plt.boxplot(data['AGE'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x247defe2e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x247defef580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x247defe2b20>],
#  'medians': [<matplotlib.lines.Line2D at 0x247defefc40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x247defeff40>],
#  'means': []}

# %% [markdown]
# # Deriving a linear regression between MV as output variable and other variables . Print mse and r square. Do with different test sizes:

# %%
data.head(9)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
#
#           PT           B  LSTAT         MV
# 0  15.300000  396.899994   4.98  24.000000
# 1  17.799999  396.899994   9.14  21.600000
# 2  17.799999  392.829987   4.03  34.700001
# 3  18.700001  394.630005   2.94  33.400002
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
df=data

# %% [markdown]
# # test size 0.1:

# %%
training_features = [ 'CRIM','RM','AGE']
target = 'MV'
X_train, X_test, Y_train, Y_test = train_test_split(df[training_features],
                                                    df[target],
                                                     test_size=0.1,  
                                                   random_state=175)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X_train,Y_train)

predicted=model.predict(X_test)
print("Mean squared error: %.2f"
              % mean_squared_error(Y_test, predicted))
print('R Square score: %.2f' % r2_score(Y_test, predicted))
# Out:
# Mean squared error: 26.06
# R Square score: 0.77

# %% [markdown]
# # test size 0.2:

# %%
training_features = [ 'CRIM','RM','AGE']
target = 'MV'
X_train, X_test, Y_train, Y_test = train_test_split(df[training_features],
                                                    df[target],
                                                     test_size=0.2,  
                                                   random_state=85)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X_train,Y_train)

predicted=model.predict(X_test)
print("Mean squared error: %.2f"
              % mean_squared_error(Y_test, predicted))
print('R Square score: %.2f' % r2_score(Y_test, predicted))
# Out:
# Mean squared error: 22.35
# R Square score: 0.73

# %% [markdown]
# # test size 0.3:

# %%
training_features = [ 'CRIM','RM','AGE']
target = 'MV'
X_train, X_test, Y_train, Y_test = train_test_split(df[training_features],
                                                    df[target],
                                                     test_size=0.3,  
                                                   random_state=18)

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

model.fit(X_train,Y_train)

predicted=model.predict(X_test)
print("Mean squared error: %.2f"
              % mean_squared_error(Y_test, predicted))
print('R Square score: %.2f' % r2_score(Y_test, predicted))
# Out:
# Mean squared error: 31.95
# R Square score: 0.61
